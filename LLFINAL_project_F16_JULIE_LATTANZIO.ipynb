# %%
print "My name is %s" % ("Julie Lattanzio")
# Out:
# My name is Julie Lattanzio

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib notebook
from numpy import random

# %% [markdown]
# # Predicting the weather
#
# ***For all of the questions in this project, assume that 1 month = 30 days.***

# %% [markdown]
# ## Problem 1 (20 pts)
#
# Suppose there is a 20% chance it will rain on any given day in a month. What are the odds that that rains on one and only one day in a month.
#
# Work this problem out a*nalytically* (with pen and paper, using a formula) and write it up in your final document.
#
# Here you should solve the same problem *numerically* using a Monte Carlo approach, similar to how we approached the birthday problem in class.
#
# Make sure that both approaches give you a similar result.

# %%
# define a function that will find percentage of rainy days

def nrain(r_days):

    if r_days <= 0.20: # percent chance of rain for that day
            
        return True # use this value
    
    else:
        
        return False

# %%
# use loops to run function over span of several months

n_months = 10000 # number of months 
totald = 0 # number of days it rains per month
totalm = 0 # number of months it rains 
n_days = 30 # number of days per month

for i in range (0,n_months): # loop for each day of month
    totald = 0

    for j in range (0,n_days): # nested loop for days
        
        r_days = np.random.random() 
        
        if nrain(r_days) == True: # used value from function
            
            totald += 1 #  append number of rainy days
                            
    if totald == 1:
                
        totalm += 1 
        

print totald
print totalm

        

print "The odds that that rains on one and only one day in a month are %0.7f" % ((float(totalm)/float(n_months))*100)
# calculation is out of n_months how many times it rained only one day that month
# Out:
# 13
# 89
# The odds that that rains on one and only one day in a month are 0.8900000

# %% [markdown]
# ## Problem 2 (20 pts)
#
# Suppose there is a 10% chance that it will rain on any given day in a month. What are the odds that it rains at least 8 days (in any order) that month?
#
# Work this problem out *numerically* using a Monte Carlo approach.

# %%
# define a function that will find percentage of rainy days

def n_rain(rdays): # different names 
    
    rdays = np.random.random() # random generator for the day that it rains

    if rdays <= 0.10: # percent chance of rain for each day
            
        return True # use this value
    
    else:
        return False # ignore later on

# %%
# use loops to run function over span of several months

n_months = 100000 # number of months 
totald = 0 # number of days it rains per month
totalm = 0 # number of months it rains 
n_days = 30 # number of days per month

for i in range (0,n_months): # loop for each day of month
    
    totald = 0
    
    for j in range (0,n_days): # nested loop for days
        
        r_days = np.random.random() 
        
        if nrain(r_days) == True: # used value from function
            
            totald += 8 #  append number of rainy days
                            
    if totald == 8:
                
        totalm += 1 
    
    
        
        

print totald
print totalm

        

print "The odds that that rains on one and only one day in a month are %0.7f" % ((float(totalm)/float(n_months))*100)
# calculation is out of n_months how many times it rained eight days per month
# Out:
# 56
# 966
# The odds that that rains on one and only one day in a month are 0.9660000

# %% [markdown]
# ## Problem 3
#
# ### 3a (20 pts)
#
# Suppose that if it rains one day, the odds of a certain amount of rainfall *on that day* are
#
# * 1 cm   20%
# * 2 cm   30%
# * 3 cm   30%
# * 4 cm   10%
# * 5 cm   10%
#
# However the odds of it raining are dependent on if it rained the day before.
#
# * If it is the first day of the month, there is a 10% chance of rain.
# * If it rained 1 day before, but not 2 days before, there is a 20% chance of rain.
# * If it rained both of the 2 days before, but not the 3rd day before, there is a 25% chance of rain.
# * If it rained for the 3 days (or more) before, there is a 5% chance of rain.
# * Otherwise, there is a 10% chance of rain
#
# What are the odds that there are at least 10 cm of rain in a given month?
#
# Work this problem out using a Monte Carlo approach.

# %%
# define a function that will find percentage of rainy days

def nrain(r_days):
    
    amount = 0

    if r_days >= 0 and r_days < 0.10:
            
        amount += 4 or 5 #  cm
        
    elif r_days >= 0.10 and r_days < 0.20:
        
        amount += 1.0
        
    elif r_days >= 0.20 and r_days < 0.30:
        
        amount += 2 or 3   
        
    return amount

# %%
# use loops to run function over span of several months

n_months = 1
n_days = 30
amount = 0
d_rain = 0
m_rain = 0

for i in range (0,n_months): # loop for each day of month
    
    for j in range (0,n_days): # nested loop for days
        
        r_days = np.random.random()
                
        for k in range (0,j):
            
            if k <= 0.10:
                d_rain += 1
                
                if d_rain == 1 and [k+1] <= 0.20:                    
                    d_rain += 2
                    
                    if d_rain == 2 and [k+2] <= 0.25:                    
                        d_rain += 3
                    
                        if d_rain == 3 and [k+3] <= 0.05:                    
                            d_rain += 4
                        
            elif k <= 0.10 and d_rain == 0:                    
                    d_rain += 1
                    
        if d_rain >= 1:
                
            if amount >= 10:
                    
                m_rain += 1     

print "The odds that there are at least 10 cm of rain in a given month are %0.7f" % ((float(m_rain)/float(n_months))*100)
# calculation is out of n_months how many times it rained more than 10 cm per month
# Out:
# The odds that there are at least 10 cm of rain in a given month are 0.0000000

# %% [markdown]
# ### 3b (10 pts)
#
# Make a histogram of the distribtion of expected rainfall values. You can get this from your Monte Carlo trials.
#
# Make sure you label everything clearly.

# %%
###################################################

def coin(): # coin flip
    
    n_random = random.random() 
    
    side = -1 
    if n_random >= 0 and n_random < 1.0/6.0:
        side = 1 # heads
        
    elif n_random >= 1.0/6.0 and n_random < 2.0/6.0:
        side = 2 # tails    
    
    return side

# %%
# Your code here
nflips = 10000

values = []
for i in range(0,nflips):
    
    value = coin()
    values.append(value)
    
plt.figure(figsize=(5,5))

plt.hist(values,range=(1,3)) 

plt.xlabel("Heads or Tails",fontsize=18)
plt.ylabel("Number of Occurances",fontsize=18)

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### 3c (10 pts)
#
# What is the average amount of rain to fall in any given month?

# %%
# Your code here

def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

mean([m_rain])
# Out:
# 0.0

# %% [markdown]
# ### 3d (20)
#
# Once you find the average value, someone might ask you for the uncertainty (some people also refer to uncertainty as the "*error*") on your prediction. That can be tricky to calculate, so often what is given is just a *range* of possible values. "We estimate the rainfall to be between X cm and Y cm." The question is, how to decide what that range is.
#
# The way this is often done is to find the middle 95% of the trial values (from your Monte Carlo run) and then use the low-edge and the high-edge of that range. If you're concerned about the middle 95%, then 2.5% of the values are below them and 2.5% of all the values are above them. The rainfall values at those edges are what you use for the ranges to quote.
#
# This is what people mean when they say, "I'm 95% confident that the rainfall will be between X and Y", and when you write it up for the LaTeX document, you should also quote it this way.
#
# *Hint!* This part becomes much easier if you sort all the values using any of the numpy/Python sort functions you can read about online. When you sort them, you should be able to find what rainfall is at the edge for the lower 2.5% and the higher 2.5%.

# %%
# Your code here

from scipy.special import erf # error function

erf(m_rain)
# Out:
# 0.0
